# %%
# !pip install -r requirements.txt

import os
import re
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from datetime import datetime

# ----------------------------
# Configuration
# ----------------------------

BASE_URL = "https://ndhrhis.doh.gov.ph"
HTML_DIR = "complete_html"
OUT_DIR = "complete_csv"
os.makedirs(OUT_DIR, exist_ok=True)

YEAR_CONFIG = {
    2024: ('02', 'As of December 31, 2024', '2025-01-03'),
    2023: ('02', 'As of December 2023', '2024-01-02'),
    2022: ('02', 'As of December 2022', '2023-01-04'),
    2021: ('03', 'As of December 2021', '2022-01-03'),
    2020: ('01', 'As of December 31, 2020', '2020-07-22'),
    2019: ('01', 'As Of December 31, 2019', '2020-01-24'), # capital "Of"
    2018: ('01', 'As of December 31, 2018', '2018-09-07'),
    2017: ('03', 'As of December 31, 2017 - Third set of test data', '2018-06-10'),
}

HEADERS = {
    "User-Agent": "Mozilla/5.0",
    "Referer": "https://ndhrhis.doh.gov.ph/RPA0001b.php",
    "Origin": "https://ndhrhis.doh.gov.ph",
    "Content-Type": "application/x-www-form-urlencoded"
}

# ----------------------------
# Helpers
# ----------------------------

def extract_dropdown_values(soup):
    sel = soup.find("select", attrs={"name": "ddparams"})
    if not sel:
        return []
    options = []
    for opt in sel.find_all("option"):
        value = opt.get("value", "").strip()
        label = opt.text.strip()
        if value and label and value.lower() != 'null':
            options.append((value, label))
    return options

def build_post_url(level, year):
    seqn, title, gdate = YEAR_CONFIG[year]
    return (f"{BASE_URL}/system.bcall.page.php?xcrs=RPA0001b.php&prm="
            f"level={level}^year={year}^seqn={seqn}^title={title}^gdate={gdate}^"
            "allfltr=0^prvslct=A^prvlist=^sbrep=A%20B%20C%20D%20E")

def get_html_for_year(year):
    path = os.path.join(HTML_DIR, f"Distribution-Nationwide {year}.html")
    with open(path, encoding="utf-8") as f:
        return BeautifulSoup(f.read(), "lxml")

def submit_and_parse(session, url, ddvalue):
    time.sleep(0.01)
    resp = session.post(url, headers=HEADERS, data={"ddparams": ddvalue, "submit": "Submit"})
    resp.raise_for_status()
    time.sleep(0.01)
    return BeautifulSoup(resp.text, "lxml")

def sanitize_filename(name):
    return re.sub(r'[^\w\s-]', '', name).replace(' ', '_')

def extract_and_save_tables(soup, outdir, place_name, year, level):
    os.makedirs(outdir, exist_ok=True)
    for table in soup.find_all("table", class_="RepT"):
        table_id = table.get("id", "")
        match = re.match(r"treport([A-Z])", table_id)
        if not match:
            continue
        category_letter = match.group(1)

        rows = table.find_all("tr")
        data = [[cell.get_text(strip=True) for cell in row.find_all(["td", "th"])]
                for row in rows if row.find_all(["td", "th"])]
        if len(data) < 2:
            continue
        df = pd.DataFrame(data[1:], columns=data[0])
        fname = f"{sanitize_filename(place_name)}_TABLE_{category_letter}.csv"
        df.to_csv(os.path.join(outdir, fname), index=False)
        print(f"✅ Saved CSV: {year}/{level}/{fname}")

# ----------------------------
# Main Routine per Year
# ----------------------------

def process_year(year):
    session = requests.Session()
    try:
        print(f"\n🔍 Processing year: {year}")
        entry_soup = get_html_for_year(year)
        region_vals = extract_dropdown_values(entry_soup)

        for region_val, region_label in region_vals:
            try:
                url_region = build_post_url(level=2, year=year)
                region_soup = submit_and_parse(session, url_region, region_val)

                region_dir = os.path.join(OUT_DIR, str(year), sanitize_filename(region_label))
                extract_and_save_tables(region_soup, region_dir, region_label, year, "Region")

                province_vals = extract_dropdown_values(region_soup)
                for province_val, province_label in province_vals:
                    try:
                        url_prov = build_post_url(level=3, year=year)
                        province_soup = submit_and_parse(session, url_prov, province_val)

                        province_dir = os.path.join(region_dir, sanitize_filename(province_label))
                        extract_and_save_tables(province_soup, province_dir, province_label, year, "Province")

                        muni_vals = extract_dropdown_values(province_soup)
                        for muni_val, muni_label in muni_vals:
                            try:
                                url_muni = build_post_url(level=4, year=year)
                                muni_soup = submit_and_parse(session, url_muni, muni_val)

                                muni_dir = os.path.join(province_dir, sanitize_filename(muni_label))
                                extract_and_save_tables(muni_soup, muni_dir, muni_label, year, "Municipality")
                            except Exception as e:
                                print(f"❌ Error in municipality {muni_label}: {e}")
                    except Exception as e:
                        print(f"❌ Error in province {province_label}: {e}")
            except Exception as e:
                print(f"❌ Error in region {region_label}: {e}")
    except Exception as e:
        print(f"❌ Could not initialize year {year}: {e}")

# ----------------------------
# Entry Point
# ----------------------------

if __name__ == "__main__":
    with ThreadPoolExecutor(max_workers=8) as executor:
        futures = [executor.submit(process_year, year) for year in sorted(YEAR_CONFIG)]
        for future in as_completed(futures):
            future.result()
# Out:
# Requirement already satisfied: requests>=2.25.1 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from -r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: beautifulsoup4>=4.9.3 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from -r requirements.txt (line 2)) (4.13.4)
# Requirement already satisfied: pandas>=1.2.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from -r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: lxml>=4.6.2 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from -r requirements.txt (line 4)) (6.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests>=2.25.1->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests>=2.25.1->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests>=2.25.1->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests>=2.25.1->-r requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: soupsieve>1.2 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from beautifulsoup4>=4.9.3->-r requirements.txt (line 2)) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from beautifulsoup4>=4.9.3->-r requirements.txt (line 2)) (4.14.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pandas>=1.2.0->-r requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pandas>=1.2.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pandas>=1.2.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from pandas>=1.2.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.0->-r requirements.txt (line 3)) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
#
# 🔍 Processing year: 2017
# 🔍 Processing year: 2018
#
#
# 🔍 Processing year: 2019
#
# 🔍 Processing year: 2020
#
# 🔍 Processing year: 2021
#
# 🔍 Processing year: 2022
#
# 🔍 Processing year: 2023
#
# 🔍 Processing year: 2024
# ✅ Saved CSV: 2017/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2017/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2017/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2017/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2017/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2022/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2022/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2022/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2022/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2022/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2023/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2023/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2019/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2023/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2019/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2023/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2019/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2019/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2023/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2019/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2018/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2018/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2018/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2018/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2018/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2021/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2021/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2021/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2021/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2021/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2020/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2020/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2020/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2020/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2020/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2023/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2023/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2023/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2023/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2023/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2018/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2018/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2018/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2018/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2018/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2019/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2019/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2019/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2019/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2019/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2024/Region/01_-_ILOCOS_REGION_TABLE_A.csv
# ✅ Saved CSV: 2024/Region/01_-_ILOCOS_REGION_TABLE_B.csv
# ✅ Saved CSV: 2024/Region/01_-_ILOCOS_REGION_TABLE_C.csv
# ✅ Saved CSV: 2024/Region/01_-_ILOCOS_REGION_TABLE_D.csv
# ✅ Saved CSV: 2024/Region/01_-_ILOCOS_REGION_TABLE_E.csv
# ✅ Saved CSV: 2021/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2021/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2021/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2021/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2021/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2020/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2020/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2020/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2020/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2020/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2022/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2022/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2022/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2022/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2022/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2024/Province/ILOCOS_NORTE_TABLE_A.csv
# ✅ Saved CSV: 2024/Province/ILOCOS_NORTE_TABLE_B.csv
# ✅ Saved CSV: 2024/Province/ILOCOS_NORTE_TABLE_C.csv
# ✅ Saved CSV: 2024/Province/ILOCOS_NORTE_TABLE_D.csv
# ✅ Saved CSV: 2024/Province/ILOCOS_NORTE_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/BACARRA_TABLE_A.csv✅ Saved CSV: 2023/Municipality/ADAMS_TABLE_A.csv
#
# ✅ Saved CSV: 2023/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/ADAMS_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/ADAMS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/ADAMS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/ADAMS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/ADAMS_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BACARRA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BACARRA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BACARRA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BACARRA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BACARRA_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BADOC_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BADOC_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BADOC_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BADOC_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BADOC_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BANGUI_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BANGUI_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BANGUI_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BANGUI_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BANGUI_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/PASUQUIN_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/PASUQUIN_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/PASUQUIN_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/PASUQUIN_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/PASUQUIN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BANNA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BANNA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BANNA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BANNA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BANNA_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/PIDDIG_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/PIDDIG_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/PIDDIG_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/PIDDIG_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/PIDDIG_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/PINILI_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/PINILI_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/PINILI_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/PINILI_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/PINILI_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BATAC_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BATAC_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BATAC_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BATAC_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BATAC_CITY_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/SAN_NICOLAS_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/SAN_NICOLAS_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/SAN_NICOLAS_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/SAN_NICOLAS_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/SAN_NICOLAS_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/SARRAT_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/SARRAT_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/SARRAT_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/SARRAT_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/SARRAT_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/SOLSONA_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/SOLSONA_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/SOLSONA_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/SOLSONA_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/SOLSONA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/VINTAR_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/VINTAR_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/VINTAR_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/VINTAR_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/VINTAR_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_SUR_TABLE_A.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_SUR_TABLE_B.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_SUR_TABLE_C.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_SUR_TABLE_D.csv
# ✅ Saved CSV: 2017/Province/ILOCOS_SUR_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CARASI_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CARASI_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CARASI_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CARASI_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CARASI_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BANAYOYO_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BANAYOYO_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BANAYOYO_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BANAYOYO_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BANAYOYO_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BANTAY_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BANTAY_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BANTAY_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BANTAY_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BANTAY_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CURRIMAO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CURRIMAO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CURRIMAO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CURRIMAO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CURRIMAO_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/CABUGAO_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/CABUGAO_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/CABUGAO_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/CABUGAO_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/CABUGAO_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/DINGRAS_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/DINGRAS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/DINGRAS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/DINGRAS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/DINGRAS_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/CANDON_CITY_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/CANDON_CITY_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/CANDON_CITY_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/CANDON_CITY_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/CANDON_CITY_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/DUMALNEG_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/DUMALNEG_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/DUMALNEG_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/DUMALNEG_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/DUMALNEG_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/CAOAYAN_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/CAOAYAN_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/CAOAYAN_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/CAOAYAN_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/CAOAYAN_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/CERVANTES_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/CERVANTES_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/CERVANTES_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/CERVANTES_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/CERVANTES_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/LAOAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/LAOAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/LAOAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/LAOAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/LAOAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/NUEVA_ERA_TABLE_A.csv✅ Saved CSV: 2021/Municipality/PAGUDPUD_TABLE_A.csv
#
# ✅ Saved CSV: 2021/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/PASUQUIN_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/PASUQUIN_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/PASUQUIN_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/PASUQUIN_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/PASUQUIN_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/GALIMUYOD_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/GALIMUYOD_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/GALIMUYOD_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/GALIMUYOD_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/GALIMUYOD_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/PASUQUIN_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/PASUQUIN_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/PASUQUIN_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/PASUQUIN_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/PASUQUIN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MARCOS_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MARCOS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MARCOS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MARCOS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MARCOS_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/GREGORIO_DEL_PILAR_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/GREGORIO_DEL_PILAR_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/GREGORIO_DEL_PILAR_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/GREGORIO_DEL_PILAR_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/GREGORIO_DEL_PILAR_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2023/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2023/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/PAGUDPUD_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/PIDDIG_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/PIDDIG_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/PIDDIG_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/PIDDIG_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/PIDDIG_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/PASUQUIN_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/PASUQUIN_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/PASUQUIN_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/PASUQUIN_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/PASUQUIN_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/MAGSINGAL_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/MAGSINGAL_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/MAGSINGAL_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/MAGSINGAL_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/MAGSINGAL_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/PIDDIG_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/PIDDIG_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/PIDDIG_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/PIDDIG_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/PIDDIG_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/PASUQUIN_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/PASUQUIN_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/PASUQUIN_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/PASUQUIN_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/PASUQUIN_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/NAGBUKEL_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/NAGBUKEL_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/NAGBUKEL_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/NAGBUKEL_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/NAGBUKEL_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/PASUQUIN_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/PASUQUIN_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/PASUQUIN_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/PASUQUIN_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/PASUQUIN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/NUEVA_ERA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/NUEVA_ERA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/NUEVA_ERA_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/PAOAY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/NUEVA_ERA_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/PAOAY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/NUEVA_ERA_TABLE_E.csv
# ✅ Saved CSV: 2023/Municipality/PAOAY_TABLE_C.csv
# ✅ Saved CSV: 2023/Municipality/PAOAY_TABLE_D.csv
# ✅ Saved CSV: 2023/Municipality/PAOAY_TABLE_E.csv
# ✅ Saved CSV: 2018/Municipality/PIDDIG_TABLE_A.csv
# ✅ Saved CSV: 2018/Municipality/PIDDIG_TABLE_B.csv
# ✅ Saved CSV: 2018/Municipality/PIDDIG_TABLE_C.csv
# ✅ Saved CSV: 2018/Municipality/PIDDIG_TABLE_D.csv
# ✅ Saved CSV: 2018/Municipality/PIDDIG_TABLE_E.csv
# ✅ Saved CSV: 2019/Municipality/PINILI_TABLE_A.csv
# ✅ Saved CSV: 2019/Municipality/PINILI_TABLE_B.csv
# ✅ Saved CSV: 2019/Municipality/PINILI_TABLE_C.csv
# ✅ Saved CSV: 2019/Municipality/PINILI_TABLE_D.csv
# ✅ Saved CSV: 2019/Municipality/PINILI_TABLE_E.csv
# ✅ Saved CSV: 2020/Municipality/PINILI_TABLE_A.csv
# ✅ Saved CSV: 2020/Municipality/PINILI_TABLE_B.csv
# ✅ Saved CSV: 2020/Municipality/PINILI_TABLE_C.csv
# ✅ Saved CSV: 2020/Municipality/PINILI_TABLE_D.csv
# ✅ Saved CSV: 2020/Municipality/PINILI_TABLE_E.csv
# ✅ Saved CSV: 2017/Municipality/NARVACAN_TABLE_A.csv
# ✅ Saved CSV: 2017/Municipality/NARVACAN_TABLE_B.csv
# ✅ Saved CSV: 2017/Municipality/NARVACAN_TABLE_C.csv
# ✅ Saved CSV: 2017/Municipality/NARVACAN_TABLE_D.csv
# ✅ Saved CSV: 2017/Municipality/NARVACAN_TABLE_E.csv
# ✅ Saved CSV: 2021/Municipality/PIDDIG_TABLE_A.csv
# ✅ Saved CSV: 2021/Municipality/PIDDIG_TABLE_B.csv
# ✅ Saved CSV: 2021/Municipality/PIDDIG_TABLE_C.csv
# ✅ Saved CSV: 2021/Municipality/PIDDIG_TABLE_D.csv
# ✅ Saved CSV: 2021/Municipality/PIDDIG_TABLE_E.csv
# ✅ Saved CSV: 2022/Municipality/PIDDIG_TABLE_A.csv
# ✅ Saved CSV: 2022/Municipality/PIDDIG_TABLE_B.csv
# ✅ Saved CSV: 2022/Municipality/PIDDIG_TABLE_C.csv
# ✅ Saved CSV: 2022/Municipality/PIDDIG_TABLE_D.csv
# ✅ Saved CSV: 2022/Municipality/PIDDIG_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PAGUDPUD_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PAGUDPUD_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PAGUDPUD_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PAGUDPUD_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PAGUDPUD_TABLE_E.csv
# ...
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BURGOS_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CLAVER_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CLAVER_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CLAVER_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CLAVER_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CLAVER_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/DAPA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/DAPA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/DAPA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/DAPA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/DAPA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/DEL_CARMEN_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/DEL_CARMEN_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/DEL_CARMEN_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/DEL_CARMEN_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/DEL_CARMEN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/GENERAL_LUNA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/GENERAL_LUNA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/GENERAL_LUNA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/GENERAL_LUNA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/GENERAL_LUNA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/GIGAQUIT_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/GIGAQUIT_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/GIGAQUIT_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/GIGAQUIT_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/GIGAQUIT_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MAINIT_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MAINIT_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MAINIT_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MAINIT_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MAINIT_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MALIMONO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MALIMONO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MALIMONO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MALIMONO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MALIMONO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PILAR_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PILAR_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PILAR_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PILAR_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PILAR_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PLACER_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PLACER_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PLACER_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PLACER_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PLACER_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SAN_BENITO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SAN_BENITO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SAN_BENITO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SAN_BENITO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SAN_BENITO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SAN_FRANCISCO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SAN_FRANCISCO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SAN_FRANCISCO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SAN_FRANCISCO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SAN_FRANCISCO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SAN_ISIDRO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SAN_ISIDRO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SAN_ISIDRO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SAN_ISIDRO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SAN_ISIDRO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SANTA_MONICA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SANTA_MONICA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SANTA_MONICA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SANTA_MONICA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SANTA_MONICA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SISON_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SISON_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SISON_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SISON_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SISON_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SOCORRO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SOCORRO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SOCORRO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SOCORRO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SOCORRO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SURIGAO_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SURIGAO_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SURIGAO_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SURIGAO_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SURIGAO_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/TAGANA-AN_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/TAGANA-AN_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/TAGANA-AN_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/TAGANA-AN_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/TAGANA-AN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/TUBOD_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/TUBOD_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/TUBOD_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/TUBOD_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/TUBOD_TABLE_E.csv
# ✅ Saved CSV: 2024/Province/SURIGAO_DEL_SUR_TABLE_A.csv
# ✅ Saved CSV: 2024/Province/SURIGAO_DEL_SUR_TABLE_B.csv
# ✅ Saved CSV: 2024/Province/SURIGAO_DEL_SUR_TABLE_C.csv
# ✅ Saved CSV: 2024/Province/SURIGAO_DEL_SUR_TABLE_D.csv
# ✅ Saved CSV: 2024/Province/SURIGAO_DEL_SUR_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BAROBO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BAROBO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BAROBO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BAROBO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BAROBO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BAYABAS_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BAYABAS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BAYABAS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BAYABAS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BAYABAS_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/BISLIG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/BISLIG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/BISLIG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/BISLIG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/BISLIG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CAGWAIT_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CAGWAIT_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CAGWAIT_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CAGWAIT_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CAGWAIT_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CANTILAN_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CANTILAN_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CANTILAN_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CANTILAN_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CANTILAN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CARMEN_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CARMEN_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CARMEN_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CARMEN_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CARMEN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CARRASCAL_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CARRASCAL_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CARRASCAL_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CARRASCAL_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CARRASCAL_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CORTES_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CORTES_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CORTES_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CORTES_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CORTES_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/HINATUAN_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/HINATUAN_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/HINATUAN_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/HINATUAN_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/HINATUAN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/LANUZA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/LANUZA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/LANUZA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/LANUZA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/LANUZA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/LIANGA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/LIANGA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/LIANGA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/LIANGA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/LIANGA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/LINGIG_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/LINGIG_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/LINGIG_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/LINGIG_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/LINGIG_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MADRID_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MADRID_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MADRID_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MADRID_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MADRID_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MARIHATAG_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MARIHATAG_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MARIHATAG_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MARIHATAG_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MARIHATAG_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SAN_AGUSTIN_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SAN_AGUSTIN_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SAN_AGUSTIN_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SAN_AGUSTIN_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SAN_AGUSTIN_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SAN_MIGUEL_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SAN_MIGUEL_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SAN_MIGUEL_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SAN_MIGUEL_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SAN_MIGUEL_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/TAGBINA_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/TAGBINA_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/TAGBINA_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/TAGBINA_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/TAGBINA_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/TAGO_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/TAGO_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/TAGO_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/TAGO_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/TAGO_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/TANDAG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/TANDAG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/TANDAG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/TANDAG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/TANDAG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Region/NCR_TABLE_A.csv
# ✅ Saved CSV: 2024/Region/NCR_TABLE_B.csv
# ✅ Saved CSV: 2024/Region/NCR_TABLE_C.csv
# ✅ Saved CSV: 2024/Region/NCR_TABLE_D.csv
# ✅ Saved CSV: 2024/Region/NCR_TABLE_E.csv
# ✅ Saved CSV: 2024/Province/NCR_2ND_DISTRICT_TABLE_A.csv
# ✅ Saved CSV: 2024/Province/NCR_2ND_DISTRICT_TABLE_B.csv
# ✅ Saved CSV: 2024/Province/NCR_2ND_DISTRICT_TABLE_C.csv
# ✅ Saved CSV: 2024/Province/NCR_2ND_DISTRICT_TABLE_D.csv
# ✅ Saved CSV: 2024/Province/NCR_2ND_DISTRICT_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MANDALUYONG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MANDALUYONG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MANDALUYONG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MANDALUYONG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MANDALUYONG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MARIKINA_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MARIKINA_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MARIKINA_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MARIKINA_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MARIKINA_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PASIG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PASIG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PASIG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PASIG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PASIG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/QUEZON_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/QUEZON_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/QUEZON_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/QUEZON_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/QUEZON_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/SAN_JUAN_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/SAN_JUAN_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/SAN_JUAN_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/SAN_JUAN_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/SAN_JUAN_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Province/NCR_3RD_DISTRICT_TABLE_A.csv
# ✅ Saved CSV: 2024/Province/NCR_3RD_DISTRICT_TABLE_B.csv
# ✅ Saved CSV: 2024/Province/NCR_3RD_DISTRICT_TABLE_C.csv
# ✅ Saved CSV: 2024/Province/NCR_3RD_DISTRICT_TABLE_D.csv
# ✅ Saved CSV: 2024/Province/NCR_3RD_DISTRICT_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/CALOOCAN_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/CALOOCAN_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/CALOOCAN_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/CALOOCAN_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/CALOOCAN_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MALABON_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MALABON_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MALABON_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MALABON_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MALABON_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/NAVOTAS_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/NAVOTAS_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/NAVOTAS_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/NAVOTAS_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/NAVOTAS_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/VALENZUELA_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/VALENZUELA_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/VALENZUELA_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/VALENZUELA_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/VALENZUELA_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Province/NCR_4TH_DISTRICT_TABLE_A.csv
# ✅ Saved CSV: 2024/Province/NCR_4TH_DISTRICT_TABLE_B.csv
# ✅ Saved CSV: 2024/Province/NCR_4TH_DISTRICT_TABLE_C.csv
# ✅ Saved CSV: 2024/Province/NCR_4TH_DISTRICT_TABLE_D.csv
# ✅ Saved CSV: 2024/Province/NCR_4TH_DISTRICT_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/LAS_PINAS_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/LAS_PINAS_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/LAS_PINAS_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/LAS_PINAS_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/LAS_PINAS_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MAKATI_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MAKATI_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MAKATI_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MAKATI_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MAKATI_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/MUNTINLUPA_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/MUNTINLUPA_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/MUNTINLUPA_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/MUNTINLUPA_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/MUNTINLUPA_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PARANAQUE_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PARANAQUE_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PARANAQUE_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PARANAQUE_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PARANAQUE_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PASAY_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PASAY_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PASAY_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PASAY_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PASAY_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/PATEROS_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/PATEROS_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/PATEROS_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/PATEROS_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/PATEROS_TABLE_E.csv
# ✅ Saved CSV: 2024/Municipality/TAGUIG_CITY_TABLE_A.csv
# ✅ Saved CSV: 2024/Municipality/TAGUIG_CITY_TABLE_B.csv
# ✅ Saved CSV: 2024/Municipality/TAGUIG_CITY_TABLE_C.csv
# ✅ Saved CSV: 2024/Municipality/TAGUIG_CITY_TABLE_D.csv
# ✅ Saved CSV: 2024/Municipality/TAGUIG_CITY_TABLE_E.csv
# ✅ Saved CSV: 2024/Province/NCR_CITY_OF_MANILA_1ST_DISTRICT_TABLE_A.csv
# ✅ Saved CSV: 2024/Province/NCR_CITY_OF_MANILA_1ST_DISTRICT_TABLE_B.csv
# ✅ Saved CSV: 2024/Province/NCR_CITY_OF_MANILA_1ST_DISTRICT_TABLE_C.csv
# ✅ Saved CSV: 2024/Province/NCR_CITY_OF_MANILA_1ST_DISTRICT_TABLE_D.csv
# ✅ Saved CSV: 2024/Province/NCR_CITY_OF_MANILA_1ST_DISTRICT_TABLE_E.csv
